# %% [markdown]
# # Interactive Training
#
# This notebook allows interactive exploration of the training process.

# %%
from src.training.train import LLMFineTuner
from src.training.config import TrainingConfig

# Configure training
config = TrainingConfig(
    epochs=1,  # Start with 1 epoch for testing
    batch_size=2,
    learning_rate=2e-5
)

finetuner = LLMFineTuner(config)
print("Configuration:", config)
